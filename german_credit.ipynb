# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Ali\\Desktop\\Python code'

# %%
os.chdir("C:/Users/Ali/Desktop/datasets")
os.getcwd()
# Out:
# 'C:\\Users\\Ali\\Desktop\\datasets'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as py
from sklearn import preprocessing

# %%
data1 = pd.read_csv('german_credit.csv')

# %%
data1
# Out:
#      Creditability  Account Balance  Duration of Credit (month)  \
# 0                1                1                          18
# 1                1                1                           9
# 2                1                2                          12
# 3                1                1                          12
# 4                1                1                          12
# 5                1                1                          10
# 6                1                1                           8
# 7                1                1                           6
# 8                1                4                          18
# 9                1                2                          24
# 10               1                1                          11
# 11               1                1                          30
# 12               1                1                           6
# 13               1                2                          48
# ...

# %%
data1.describe()
# Out:
#        Creditability  Account Balance  Duration of Credit (month)  \
# count    1000.000000      1000.000000                 1000.000000
# mean        0.700000         2.577000                   20.903000
# std         0.458487         1.257638                   12.058814
# min         0.000000         1.000000                    4.000000
# 25%         0.000000         1.000000                   12.000000
# 50%         1.000000         2.000000                   18.000000
# 75%         1.000000         4.000000                   24.000000
# max         1.000000         4.000000                   72.000000
#
#        Payment Status of Previous Credit      Purpose  Credit Amount  \
# count                         1000.00000  1000.000000     1000.00000
# mean                             2.54500     2.828000     3271.24800
# std                              1.08312     2.744439     2822.75176
# min                              0.00000     0.000000      250.00000
# ...

# %%
data1.cov()
# Out:
#                                    Creditability  Account Balance  \
# Creditability                           0.210210         0.202302
# Account Balance                         0.202302         1.581653
# Duration of Credit (month)             -1.188288        -1.092123
# Payment Status of Previous Credit       0.113614         0.261797
# Purpose                                -0.022623         0.099343
# Credit Amount                        -200.263864      -151.567664
# Value Savings/Stocks                    0.129630         0.442858
# Length of current employment            0.064264         0.161594
# Instalment per cent                    -0.037137        -0.007428
# Sex & Marital Status                    0.028629         0.038525
# Guarantors                              0.005506        -0.076742
# Duration in Current address            -0.001502        -0.058624
# Most valuable available asset          -0.068669        -0.042609
# ...

# %%
data1.corr()
# Out:
#                                    Creditability  Account Balance  \
# Creditability                           1.000000         0.350847
# Account Balance                         0.350847         1.000000
# Duration of Credit (month)             -0.214927        -0.072013
# Payment Status of Previous Credit       0.228785         0.192191
# Purpose                                -0.017979         0.028783
# Credit Amount                          -0.154740        -0.042695
# Value Savings/Stocks                    0.178943         0.222867
# Length of current employment            0.116002         0.106339
# Instalment per cent                    -0.072404        -0.005280
# Sex & Marital Status                    0.088184         0.043261
# Guarantors                              0.025137        -0.127737
# Duration in Current address            -0.002967        -0.042234
# Most valuable available asset          -0.142612        -0.032260
# ...

# %%
# %matplotlib inline

# %%
data1['Account Balance'].hist(bins=10)

# %%
data1['Age (years)'].hist(bins=10)

# %%
data1['Credit Amount'].hist(bins=10)

# %%
data1['Duration of Credit (month)'].hist(bins=10)

# %%
data1.boxplot(column='Duration of Credit (month)')

# %%
data1.boxplot(column='Credit Amount')

# %%
data1.boxplot(column='Age (years)')

# %%
data1
# Out:
#      Creditability  Account Balance  Duration of Credit (month)  \
# 0                1                1                          18
# 1                1                1                           9
# 2                1                2                          12
# 3                1                1                          12
# 4                1                1                          12
# 5                1                1                          10
# 6                1                1                           8
# 7                1                1                           6
# 8                1                4                          18
# 9                1                2                          24
# 10               1                1                          11
# 11               1                1                          30
# 12               1                1                           6
# 13               1                2                          48
# ...

# %%
x=data1.loc[:, ['Duration of Credit (month)','Age (years)','Credit Amount']]
x.describe()
# Out:
#        Duration of Credit (month)  Age (years)  Credit Amount
# count                 1000.000000   1000.00000     1000.00000
# mean                    20.903000     35.54200     3271.24800
# std                     12.058814     11.35267     2822.75176
# min                      4.000000     19.00000      250.00000
# 25%                     12.000000     27.00000     1365.50000
# 50%                     18.000000     33.00000     2319.50000
# 75%                     24.000000     42.00000     3972.25000
# max                     72.000000     75.00000    18424.00000

# %%
x=data1.iloc[:,1:12]
y=data1.iloc[:,1]
x
# Out:
#      Account Balance  Duration of Credit (month)  \
# 0                  1                          18
# 1                  1                           9
# 2                  2                          12
# 3                  1                          12
# 4                  1                          12
# 5                  1                          10
# 6                  1                           8
# 7                  1                           6
# 8                  4                          18
# 9                  2                          24
# 10                 1                          11
# 11                 1                          30
# 12                 1                           6
# 13                 2                          48
# 14                 1                          18
# 15                 1                           6
# 16                 1                          11
# 17                 2                          18
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      2
# 3      1
# 4      1
# 5      1
# 6      1
# 7      1
# 8      4
# 9      2
# 10     1
# 11     1
# 12     1
# 13     2
# 14     1
# 15     1
# 16     1
# 17     2
# 18     2
# 19     4
# 20     1
# 21     2
# 22     2
# 23     2
# 24     1
# 25     2
# 26     1
# 27     2
# 28     4
# 29     3
#       ..
# 970    4
# 971    2
# 972    3
# 973    1
# 974    1
# 975    1
# 976    2
# 977    1
# 978    2
# 979    1
# 980    2
# 981    4
# 982    2
# 983    1
# 984    1
# 985    4
# 986    1
# 987    1
# 988    1
# 989    2
# 990    1
# 991    2
# 992    1
# 993    1
# 994    1
# 995    1
# 996    1
# 997    4
# 998    2
# 999    1
# Name: Account Balance, Length: 1000, dtype: int64

# %%
from sklearn import preprocessing 
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# array([[0.        , 0.20588235, 1.        , ..., 0.33333333, 0.        ,
#         1.        ],
#        [0.        , 0.07352941, 1.        , ..., 0.66666667, 0.        ,
#         0.33333333],
#        [0.33333333, 0.11764706, 0.5       , ..., 0.33333333, 0.        ,
#         1.        ],
#        ...,
#        [1.        , 0.25      , 1.        , ..., 0.66666667, 0.        ,
#         1.        ],
#        [0.33333333, 0.11764706, 0.5       , ..., 0.66666667, 0.        ,
#         0.        ],
#        [0.        , 0.38235294, 0.5       , ..., 0.66666667, 0.        ,
#         1.        ]])

# %%
x['Credit Amount'].describe()
# Out:
# count     1000.00000
# mean      3271.24800
# std       2822.75176
# min        250.00000
# 25%       1365.50000
# 50%       2319.50000
# 75%       3972.25000
# max      18424.00000
# Name: Credit Amount, dtype: float64

# %%
from sklearn import cross_validation, neighbors
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      Account Balance  Duration of Credit (month)  \
# 601                4                          24
# 880                1                          18
# 778                2                          18
# 158                2                          48
# 98                 1                           9
# 709                4                          48
# 972                3                          18
# 382                4                          60
# 927                1                          12
# 775                1                          36
# 758                2                          30
# 199                4                          48
# 223                4                          27
# 487                2                          18
# 185                4                          36
# 396                2                          24
# 764                4                          24
# 574                2                          36
# ...

# %%
y_train
# Out:
# 601    4
# 880    1
# 778    2
# 158    2
# 98     1
# 709    4
# 972    3
# 382    4
# 927    1
# 775    1
# 758    2
# 199    4
# 223    4
# 487    2
# 185    4
# 396    2
# 764    4
# 574    2
# 754    2
# 676    1
# 82     2
# 297    4
# 392    3
# 779    4
# 994    1
# 302    3
# 855    1
# 318    4
# 825    2
# 277    2
#       ..
# 143    4
# 4      1
# 562    2
# 77     4
# 827    1
# 249    4
# 577    1
# 698    2
# 380    1
# 485    4
# 860    4
# 819    4
# 955    1
# 234    2
# 107    4
# 816    3
# 54     4
# 857    1
# 12     1
# 761    1
# 821    1
# 530    4
# 526    1
# 5      1
# 268    4
# 602    1
# 585    1
# 636    1
# 907    1
# 113    4
# Name: Account Balance, Length: 800, dtype: int64

# %%
x_test
# Out:
#      Account Balance  Duration of Credit (month)  \
# 619                2                          12
# 89                 2                          24
# 788                2                          24
# 973                1                          45
# 551                4                          12
# 623                1                          12
# 734                1                          36
# 450                2                          12
# 640                1                          36
# 915                1                          18
# 793                1                          12
# 856                1                          24
# 978                2                          12
# 240                4                          15
# 503                4                          24
# 988                1                          18
# 621                4                          24
# 253                4                          36
# ...

# %%
y_test
# Out:
# 619    2
# 89     2
# 788    2
# 973    1
# 551    4
# 623    1
# 734    1
# 450    2
# 640    1
# 915    1
# 793    1
# 856    1
# 978    2
# 240    4
# 503    4
# 988    1
# 621    4
# 253    4
# 404    4
# 284    1
# 641    3
# 870    1
# 292    4
# 99     2
# 55     1
# 447    4
# 954    3
# 415    4
# 944    1
# 303    4
#       ..
# 752    2
# 905    1
# 270    4
# 442    1
# 340    4
# 716    1
# 194    4
# 745    4
# 418    4
# 488    4
# 464    2
# 497    4
# 425    4
# 398    4
# 329    4
# 921    1
# 867    2
# 817    1
# 769    1
# 343    4
# 554    2
# 990    1
# 845    2
# 414    4
# 729    2
# 547    3
# 421    2
# 412    4
# 363    4
# 181    4
# Name: Account Balance, Length: 200, dtype: int64

# %%
from sklearn.linear_model.logistic import LogisticRegression

cls =LogisticRegression(random_state =0)

lr_cls=cls.fit(x_train, y_train)

# %%
lr_y_test =lr_cls.predict(x_test)
lr_y_test
# Out:
# array([2, 2, 2, 1, 4, 1, 1, 2, 1, 1, 1, 1, 2, 4, 4, 1, 4, 4, 4, 1, 4, 1,
#        4, 2, 1, 4, 4, 4, 1, 4, 2, 4, 4, 2, 1, 4, 2, 4, 2, 4, 4, 4, 1, 4,
#        4, 2, 4, 1, 1, 4, 4, 4, 2, 2, 1, 1, 1, 4, 2, 4, 4, 4, 4, 4, 2, 4,
#        1, 1, 4, 1, 1, 4, 4, 1, 2, 4, 2, 2, 2, 4, 1, 4, 4, 4, 2, 4, 1, 1,
#        1, 2, 1, 4, 1, 2, 4, 4, 4, 2, 4, 2, 1, 1, 4, 2, 1, 1, 2, 2, 4, 1,
#        4, 4, 1, 4, 4, 2, 2, 4, 4, 4, 4, 2, 4, 1, 4, 1, 4, 2, 2, 1, 1, 2,
#        2, 2, 4, 2, 1, 1, 4, 2, 2, 4, 1, 2, 1, 1, 4, 2, 1, 4, 4, 2, 1, 2,
#        2, 2, 4, 4, 4, 1, 1, 4, 1, 1, 4, 4, 4, 4, 4, 4, 2, 1, 4, 1, 4, 1,
#        4, 4, 4, 4, 2, 4, 4, 4, 4, 1, 2, 1, 1, 4, 2, 1, 2, 4, 2, 4, 2, 4,
#        4, 4], dtype=int64)

# %%
lr_y_train = lr_cls.predict(x_train)
lr_y_train
# Out:
# array([4, 1, 2, 2, 1, 4, 2, 4, 1, 1, 2, 4, 4, 2, 4, 2, 4, 2, 2, 1, 2, 4,
#        4, 4, 1, 4, 1, 4, 2, 2, 4, 1, 4, 4, 1, 1, 1, 1, 4, 2, 2, 4, 1, 2,
#        1, 1, 2, 4, 1, 2, 4, 1, 4, 2, 4, 1, 1, 4, 2, 2, 4, 2, 2, 4, 1, 2,
#        4, 2, 1, 2, 4, 4, 1, 2, 4, 2, 4, 2, 1, 1, 1, 1, 1, 1, 4, 2, 2, 2,
#        1, 2, 4, 2, 4, 4, 4, 1, 1, 2, 4, 4, 4, 2, 4, 4, 2, 2, 4, 2, 4, 4,
#        4, 4, 4, 4, 4, 2, 1, 4, 4, 4, 4, 4, 4, 1, 4, 4, 1, 4, 4, 4, 1, 4,
#        2, 1, 4, 1, 2, 4, 4, 2, 4, 4, 2, 1, 2, 4, 4, 1, 1, 1, 2, 1, 2, 2,
#        4, 2, 4, 4, 4, 4, 1, 2, 4, 4, 4, 4, 4, 4, 1, 1, 2, 1, 2, 1, 4, 4,
#        2, 2, 4, 1, 2, 1, 1, 4, 2, 1, 4, 4, 2, 4, 4, 4, 4, 4, 1, 4, 1, 1,
#        4, 1, 1, 2, 4, 4, 2, 1, 4, 1, 1, 4, 2, 4, 1, 4, 1, 4, 4, 2, 4, 4,
#        2, 2, 1, 4, 1, 4, 2, 4, 4, 1, 1, 2, 1, 4, 1, 1, 4, 4, 1, 4, 2, 4,
#        4, 4, 4, 2, 4, 1, 1, 2, 2, 1, 4, 4, 4, 4, 1, 2, 2, 4, 4, 1, 2, 1,
#        1, 4, 4, 4, 2, 4, 4, 1, 2, 2, 4, 4, 2, 1, 4, 2, 4, 4, 1, 1, 2, 1,
# ...

# %%
from sklearn.metrics import confusion_matrix
lr_cm_test = confusion_matrix(y_test, lr_y_test)
lr_cm_test
# Out:
# array([[57,  0,  0,  0],
#        [ 1, 51,  0,  0],
#        [ 0,  0,  0, 13],
#        [ 0,  0,  0, 78]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
lr_accu_test= accuracy_score(y_test,lr_y_test)
lr_accu_test
# Out:
# 0.93

# %%
lr_accu_train= accuracy_score(y_train,lr_y_train)  #train 98--rs=50  
lr_accu_train
# Out:
# 0.9225

# %%
from sklearn.metrics import precision_score

lr_precision_test =precision_score(y_test, lr_y_test, average='weighted')  
print(lr_precision_test)
lr_precision_train =precision_score(y_train, lr_y_train, average='weighted')
print(lr_precision_train)
# Out:
# 0.8743719211822659
# 0.8891357832704665
# B:\Users\Ali\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.ensemble import RandomForestClassifier
rmf = RandomForestClassifier(max_depth=3, random_state=0)
rf_classi = rmf.fit(x_train, y_train)

# %%
rf_y_test = rf_classi.predict(x_test)
rf_y_test
# Out:
# array([2, 2, 2, 1, 4, 1, 1, 2, 1, 1, 1, 2, 2, 4, 4, 1, 4, 4, 4, 2, 2, 1,
#        4, 2, 1, 4, 2, 4, 1, 4, 2, 4, 4, 2, 2, 4, 2, 4, 2, 2, 4, 4, 1, 4,
#        4, 2, 4, 1, 2, 4, 4, 2, 2, 2, 1, 1, 1, 4, 2, 4, 4, 4, 4, 4, 2, 4,
#        1, 1, 2, 1, 1, 4, 4, 2, 2, 4, 2, 2, 2, 4, 1, 4, 1, 2, 2, 4, 1, 1,
#        1, 2, 1, 4, 1, 2, 4, 4, 4, 2, 4, 2, 1, 1, 4, 2, 1, 1, 2, 2, 4, 2,
#        4, 4, 1, 4, 2, 2, 2, 4, 4, 4, 4, 2, 4, 1, 4, 1, 4, 2, 2, 1, 1, 2,
#        2, 2, 4, 2, 1, 1, 4, 2, 2, 4, 1, 2, 1, 1, 4, 2, 1, 4, 4, 2, 2, 2,
#        2, 2, 4, 2, 2, 1, 2, 2, 1, 1, 4, 4, 2, 4, 4, 4, 2, 1, 4, 2, 4, 1,
#        4, 4, 4, 4, 2, 4, 4, 4, 4, 1, 2, 1, 2, 4, 2, 1, 2, 4, 2, 2, 2, 4,
#        4, 4], dtype=int64)

# %%
rf_y_train = rf_classi.predict(x_train)
rf_y_train
# Out:
# array([4, 1, 2, 2, 1, 4, 2, 4, 1, 1, 2, 4, 4, 2, 4, 2, 4, 2, 2, 1, 2, 4,
#        2, 4, 1, 2, 1, 4, 2, 2, 4, 1, 4, 4, 2, 1, 2, 2, 2, 2, 2, 4, 1, 2,
#        1, 1, 2, 4, 2, 2, 4, 1, 2, 2, 4, 1, 1, 4, 2, 2, 4, 2, 2, 4, 1, 2,
#        4, 2, 1, 2, 4, 4, 2, 2, 4, 2, 4, 2, 1, 1, 1, 1, 1, 1, 4, 2, 2, 2,
#        1, 2, 2, 2, 2, 4, 4, 1, 1, 2, 2, 4, 4, 2, 4, 4, 2, 2, 4, 2, 4, 4,
#        4, 4, 2, 4, 4, 2, 1, 2, 4, 4, 4, 4, 1, 1, 2, 4, 1, 4, 4, 4, 2, 4,
#        2, 1, 4, 1, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 4, 1, 1, 1, 2, 1, 2, 2,
#        4, 2, 4, 4, 4, 4, 1, 2, 4, 2, 4, 2, 4, 2, 1, 1, 2, 1, 2, 1, 4, 4,
#        2, 2, 4, 2, 1, 2, 1, 4, 2, 2, 4, 4, 2, 4, 2, 4, 4, 4, 1, 4, 1, 2,
#        4, 1, 1, 2, 4, 4, 2, 1, 2, 1, 1, 4, 2, 4, 1, 4, 1, 4, 4, 1, 4, 4,
#        1, 2, 2, 4, 2, 4, 2, 4, 4, 1, 1, 2, 1, 4, 2, 1, 4, 4, 1, 2, 2, 4,
#        4, 4, 4, 2, 4, 1, 2, 2, 2, 1, 4, 4, 4, 4, 1, 2, 2, 4, 4, 1, 2, 1,
#        1, 4, 2, 4, 2, 4, 4, 1, 2, 2, 4, 4, 2, 2, 4, 2, 4, 4, 1, 1, 2, 1,
# ...

# %%
from sklearn.metrics import confusion_matrix
rf_cm_test = confusion_matrix(y_test, rf_y_test)
rf_cm_test
# Out:
# array([[48,  9,  0,  0],
#        [ 0, 52,  0,  0],
#        [ 1, 12,  0,  0],
#        [ 0,  0,  0, 78]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
rf_accu_test= accuracy_score(y_test,rf_y_test)  #test
rf_accu_test
# Out:
# 0.89

# %%
rf_accu_train= accuracy_score(y_train,rf_y_train)  
rf_accu_train
# Out:
# 0.885

# %%
from sklearn.metrics import precision_score
rf_precision_test =precision_score(y_test, rf_y_test, average='weighted')  
print(rf_precision_test)  #test data
rf_precision_train =precision_score(y_train, rf_y_train, average='weighted')
print(rf_precision_train) #train data
# Out:
# 0.8543891529214426
# 0.8524987264391237
# B:\Users\Ali\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
seed = 7
num_trees = 30
kfold = model_selection.KFold(n_splits=10, random_state=seed)
model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
results = model_selection.cross_val_score(model, x_train, y_train, cv=kfold)

# %%
print(results.mean())
# Out:
# 0.9375

# %%
data1['Duration of Credit (month)'].mean()
# Out:
# 20.903

# %%
data1['Credit Amount'].mean()
# Out:
# 3271.248

# %%
data1['Age (years)'].mean()
# Out:
# 35.542

# %%
import statsmodels.api as sm
model=sm.OLS(data1['Credit Amount'],data1['Age (years)']).fit()
model1=sm.OLS(data1['Credit Amount'],data1['Duration of Credit (month)']).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Credit Amount   R-squared:                       0.530
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     1125.
# Date:                Thu, 21 Mar 2019   Prob (F-statistic):          7.84e-166
# Time:                        11:28:08   Log-Likelihood:                -9412.7
# No. Observations:                1000   AIC:                         1.883e+04
# Df Residuals:                     999   BIC:                         1.883e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Age (years)    84.2679      2.512     33.543      0.000      79.338      89.198
# ...

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Credit Amount   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     2835.
# Date:                Thu, 21 Mar 2019   Prob (F-statistic):          5.03e-294
# Time:                        11:25:31   Log-Likelihood:                -9117.4
# No. Observations:                1000   AIC:                         1.824e+04
# Df Residuals:                     999   BIC:                         1.824e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...
